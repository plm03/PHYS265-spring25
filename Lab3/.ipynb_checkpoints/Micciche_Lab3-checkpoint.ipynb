# %% [markdown]
# # Peter Micciche Lab 3

# %% [markdown]
# ## Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# df = pd.read_csv('atlas_z_to_ll.csv', delimiter = ',')
df = np.loadtxt('atlas_z_to_ll.csv', delimiter = ',', skiprows=1)

# %%
# def px(pT, phi):
#     return pT * np.cos(phi)

# def py(pT, phi):
#     return pT * np.sin(phi)

# def pz(pT, eta):
#     return np.sinh(eta)

# def M(E, px, py, pz):
#     return np.sqrt(E**2 - (px**2 + py**2 + pz**2))
    
# # calculate E 1 and 2, px 1 and 2, py 1 and 2, pz 1 and 2 for each of the lepton pair, then sum them to E, px, py, pz, then put them into the M formula

# # columns:    pT1    pT2     eta1    eta2    phi1    phi2    E1    E2

# # def p_calcs(pT1, pT2, eta1, eta2, phi1, phi2, E1, E2):
# #     px1, px2, py1, py2, pz1, pz2 = np.empty_like(df.pt1)
# #     for i in range(len(df.pt1)):
# #         px1[i], px2[i] = px(pT1[i], phi1[i]), px(pT2[i], phi2[i])
# #         py1[i], py2[i] = py(pT1[i], phi1[i]), py(pT2[i], phi2[i])
# #         pz1[i], pz2[i] = pz(pT1[i], eta1[i]), pz(pT2[i], eta2[i])

# #         px, py, pz, E = np.empty_like(df.pt1)
# #         px[i] = px1[i] + px2[i]
# #         py[i] = py1[i] + py2[i]
# #         pz[i] = pz1[i] + pz2[i]
# #         E[i] = E1[i] + E2[i]

# #     return px, py, pz, E

# def p_calcs(pT1, pT2, eta1, eta2, phi1, phi2, E1, E2):
#     # px1, px2, py1, py2, pz1, pz2 = np.empty_like(df.pt1)
#     for i in range(len(df[:,0])):
#         px1, px2 = px(pT1, phi1), px(pT2, phi2)
#         py1, py2 = py(pT1, phi1), py(pT2, phi2)
#         pz1, pz2 = pz(pT1, eta1), pz(pT2, eta2)

#         px = px1 + px2
#         py = py1 + py2
#         pz = pz1 + pz2
#         E = E1 + E2

#     return px, py, pz, E

# p_calcs = np.vectorize(p_calcs)

# # p_calcs = p_calcs(df.pt1, df.pt2, df.eta1, df.eta2, df.phi1, df.phi2, df.E1, df.E2)
# p_cacls1 = p_calcs(df[:,0],df[:,1],df[:,2],df[:,3],df[:,4],df[:,5],df[:,6],df[:,7])

# %%
# columns:    pT1    pT2     eta1    eta2    phi1    phi2    E1    E2

pt1 = df[:,0]
pt2 = df[:,1]
eta1 = df[:,2]
eta2 = df[:,3]
phi1 = df[:,4]
phi2 = df[:,5]
E1 = df[:,6]
E2 = df[:,7]

def M(pt1, pt2, eta1, eta2, phi1, phi2, E1, E2):
    px1 = pt1 * np.cos(phi1)
    px2 = pt2 * np.cos(phi2)
    pxtot = px1 + px2
    py1 = pt1 * np.sin(phi1)
    py2 = pt2 * np.sin(phi2)
    pytot = py1 + py2
    pz1 = pt1 * np.sinh(eta1)
    pz2 = pt2 * np.sinh(eta2)
    pztot = pz1 + pz2
    p2tot = pxtot**2 + pytot**2 + pztot**2
    Etot = E1 + E2

    M = np.sqrt(Etot**2 - (p2tot))
    return M

M_calc = M(pt1, pt2, eta1, eta2, phi1, phi2, E1, E2)

fig, ax = plt.subplots()
bins = np.linspace(80,100,41)
hist = ax.hist(M_calc, bins=bins);
bin_centers = (bins[:-1] + bins[1:]) / 2
yerr = ax.errorbar(bin_centers, hist[0], np.sqrt(hist[0]), fmt=',k')
ax.set_xlabel('Invariant Mass (GeV)')
ax.set_title(r'Invariant Mass of the $Z^0$-Bozon')
ax.set_ylabel('Counts');

hist[0]
# Out:
# (array([ 15.,  17.,  26.,  27.,  26.,  30.,  35.,  27.,  63.,  48.,  67.,
#          60.,  74., 107., 128., 129., 179., 201., 230., 258., 232., 262.,
#         215., 205., 194., 147., 145., 105.,  99.,  50.,  60.,  45.,  45.,
#          27.,  24.,  25.,  13.,  14.,  21.,  22.]),)

# %% [markdown]
# # Part 2

# %%
mZ0 = 91.1880   # GeV / c^2
from scipy.optimize import curve_fit

def D(m, m0, gamma):
    return 2500 * ((1/np.pi) * (gamma/2)/((m-m0)**2 + (gamma/2)**2))

err = np.sqrt(hist[0])

mask = (bin_centers > 87) & (bin_centers < 93)
bins_fit = bin_centers[mask]
hist_fit = hist[0][mask]
err_fit = err[mask]

params, covar = curve_fit(D, bins_fit, hist_fit, sigma=err_fit, absolute_sigma=True)

fig, ax = plt.subplots()
bins = np.linspace(80,100,41)
hist = ax.hist(M_calc, bins=bins, label='Counts per Mass Bin');
bin_centers = (bins[:-1] + bins[1:]) / 2
ax.errorbar(bin_centers, hist[0], np.sqrt(hist[0]), fmt=',k', label = 'Error')
ax.set_xlabel('Invariant Mass (GeV)')
ax.set_title(r'Invariant Mass of the $Z^0$-Bozon')
ax.set_ylabel('Counts')
ax.plot(bin_centers, D(bin_centers, params[0], params[1]), label='Breit-Wigner Fit')
ax.legend();
